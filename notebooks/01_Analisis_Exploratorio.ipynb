# %% [markdown]
# ## Analisis exploratorio de datos

# %% [markdown]
# ### 1. Se importan librerias necesarias

# %%
import pandas as pd

# %% [markdown]
# ### 2. Se carga el dataset

# %%
df = pd.read_csv('../data/raw/complete_renewable_energy_dataset.csv')

# %% [markdown]
# ### 3. Información básica del dataset

# %%
df.head()
# Out:
#      Country  Year Energy Type  Production (GWh)  Installed Capacity (MW)  \
# 0        USA  2011       Solar      85404.690027              5549.794323
# 1  Australia  2008  Geothermal      22205.069382             43211.593798
# 2     Canada  2013     Biomass      94102.732038              6139.117212
# 3      Japan  2010     Biomass      88771.932910             40323.639260
# 4      China  2018       Solar      93288.408581             30755.403056
#
#    Investments (USD)  Population           GDP  Energy Consumption  \
# 0       5.604125e+09  1064007213  1.775278e+14       369654.644184
# 1       6.361886e+08  1033255852  6.435372e+13       771781.636293
# 2       6.158680e+09    14895124  1.567926e+14       342707.152899
# 3       8.526116e+09  1448827283  1.350464e+14       498839.574253
# 4       5.086237e+09  1499494307  8.677956e+13       819064.362785
#
#    Energy Exports  ...  Economic Freedom Index  Ease of Doing Business  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 56 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  2500 non-null   object
#  1   Year                                     2500 non-null   int64
#  2   Energy Type                              2500 non-null   object
#  3   Production (GWh)                         2500 non-null   float64
#  4   Installed Capacity (MW)                  2500 non-null   float64
#  5   Investments (USD)                        2500 non-null   float64
#  6   Population                               2500 non-null   int64
#  7   GDP                                      2500 non-null   float64
#  8   Energy Consumption                       2500 non-null   float64
#  9   Energy Exports                           2500 non-null   float64
# ...

# %% [markdown]
# #### Campos presentes en el dataset
#
#  *   Country: País, tipo dato: object
#  *   Year: Año, tipo dato: int64
#  *   Energy Type: Tipo de energia, tipo dato: object
#  *   Production (GWh): Producción de energia, tipo dato: float64
#  *   Installed Capacity (MW): Capacidad instalada , tipo dato: float64
#  *   Investments (USD): Inversión, tipo dato: float64
#  *   Population: Población, tipo dato: int64
#  *   GDP: Indice GDP, tipo dato: float64
#  *   Energy Consumption: Consumo de energia, tipo dato: float64
#  *   Energy Exports: Exportación de energia, tipo dato: float64
#  *   Energy Imports: Importación de energia, tipo dato: float64
#  *   CO2 Emissions: Emisiones de CO2, tipo dato: float64
#  *   Renewable Energy Jobs: Empleos en energia renovable, tipo dato: int64
#  *   Government Policies: Politicas guvernamentales , tipo dato: int64
#  *   R&D Expenditure: Gastos en investigación y desarrollo, tipo dato: float64
#  *   Renewable Energy Targets: Objetivos de energia renovable, tipo dato: int64
#  *   Average Annual Temperature: Temperatura anual promedio, tipo dato: float64
#  *   Annual Rainfall: Lluvia anual, tipo dato: float64
#  *   Solar Irradiance: Radiación solar, tipo dato: float64
#  *   Wind Speed: Velorcidad del viento, tipo dato: float64
#  *   Hydro Potential: Potencial hidrico, tipo dato: float64
#  *   Geothermal Potential: Potencial geotermico, tipo dato: float64
#  *   Biomass Availability: Biomasa disponible, tipo dato: float64
#  *   Energy Storage Capacity: Capacidad de almacenamiento de energia, tipo dato: float64
#  *   Grid Integration Capability: Capacidad de integración a la red, tipo dato: float64
#  *   Electricity Prices: Precios de la energia, tipo dato: float64
#  *   Energy Subsidies: Subsidios a la energia, tipo dato: float64
#  *   International Aid for Renewables: Ayuda internacional por renovables, tipo dato: float64
#  *   Public Awareness: Conciencia publica, tipo dato: float64
#  *   Energy Efficiency Programs: Programa de eficiencia energetica, tipo dato: int64
#  *   Urbanization Rate: Porcentaje de urbanización, tipo dato: float64
#  *   Industrialization Rate: Porcentaje de industrialización, tipo dato: float64
#  *   Energy Market Liberalization: Liberalización del mercado energetico, tipo dato: int64
#  *   Renewable Energy Patents: Patentes de energia renovable, tipo dato: int64
#  *   Educational Level: Nivel de educación, tipo dato: float64
#  *   Technology Transfer Agreements: Acuerdos de transferencia tecnológica, tipo dato: int64
#  *   Renewable Energy Education Programs: Programas de educación en energias renovables, tipo dato: int64
#  *   Local Manufacturing Capacity: Capacidad de manufactura local, tipo dato: float64
#  *   Import Tariffs on Energy Equipment: Tarifas de importación en equipamiento de energia renovable, tipo dato: float64
#  *   Export Incentives for Energy Equipment: Iniciativas de exportación de equipo para energias renovables, tipo dato: float64
#  *   Natural Disasters: Desastres naturales, tipo dato: int64
#  *   Political Stability: Estabilidad politica, tipo dato: float64
#  *   Corruption Perception Index: Indice de corrupción, tipo dato: float64
#  *   Regulatory Quality: Calidad de regulación, tipo dato: float64
#  *   Rule of Law: Imperio de la ley, tipo dato: float64
#  *   Control of Corruption: Control de la corrupción, tipo dato: float64
#  *   Economic Freedom Index: Indice de libertad económica, tipo dato: float64
#  *   Ease of Doing Business: Facilidad para realizar negocios, tipo dato: float64
#  *   Innovation Index: Indice de inovación, tipo dato: float64
#  *   Number of Research Institutions: Número de instituciones de investigación, tipo dato: int64
#  *   Number of Renewable Energy Conferences: Número de conferencias sobre energia renovable, tipo dato: int64
#  *   Number of Renewable Energy Publications: Número de publicaciones sobre energia renovable, tipo dato: int64
#  *   Energy Sector Workforce: Fuerza de trabajo del sector de energia, tipo dato: int64
#  *   Proportion of Energy from Renewables: Proporción de energia obtenida de renovables, tipo dato: float64
#  *   Public-Private Partnerships in Energy: Alianzas publico-privadas en energia, tipo dato: int64
#  *   Regional Renewable Energy Cooperation: Coperación regional en energia renovable, tipo dato: int64

# %% [markdown]
# Información estadistica del dataset

# %%
df.describe()
# Out:
#               Year  Production (GWh)  Installed Capacity (MW)  \
# count  2500.000000       2500.000000              2500.000000
# mean   2011.437600      48743.195073             24882.910674
# std       6.895471      28340.915147             14463.459958
# min    2000.000000       1053.354158               114.531639
# 25%    2006.000000      24309.656479             12282.213159
# 50%    2011.000000      47367.117600             24689.162460
# 75%    2017.250000      73079.452832             37438.443570
# max    2023.000000      99937.503719             49997.387577
#
#        Investments (USD)    Population           GDP  Energy Consumption  \
# count       2.500000e+03  2.500000e+03  2.500000e+03         2500.000000
# mean        4.956155e+09  7.458927e+08  1.010745e+14       495701.245158
# std         2.894789e+09  4.373146e+08  5.782363e+13       291419.017957
# min         5.886994e+06  1.255357e+06  5.603965e+10         1264.851083
# ...

# %% [markdown]
# ### 4. Revisión de la calidad del dataset

# %% [markdown]
# Revisamos si existen registros nulos que puedan interferir con estas metricas

# %%
df.isnull().sum()
# Out:
# Country                                    0
# Year                                       0
# Energy Type                                0
# Production (GWh)                           0
# Installed Capacity (MW)                    0
# Investments (USD)                          0
# Population                                 0
# GDP                                        0
# Energy Consumption                         0
# Energy Exports                             0
# Energy Imports                             0
# CO2 Emissions                              0
# Renewable Energy Jobs                      0
# Government Policies                        0
# R&D Expenditure                            0
# Renewable Energy Targets                   0
# Average Annual Temperature                 0
# Annual Rainfall                            0
# Solar Irradiance                           0
# Wind Speed                                 0
# Hydro Potential                            0
# ...

# %% [markdown]
# Revisamos si existen datos duplicados

# %%
df.duplicated(keep=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# Length: 2500, dtype: bool

# %% [markdown]
# **Conclusión :** El dataset es de buena calidad ya que no se ha encontrado registros con valores nulos ni duplicados
